# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("dulieuxettuyendaihoc.csv")
data.head(10)
# Out:
#    STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...   X6   D6   N6  GT  \
# 0    1  7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  6.6  7.6  5.9   F
# 1    2  5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...  6.6  6.1  4.4   M
# 2    3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  7.9  8.1  4.6   M
# 3    4  6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  7.1  7.3  7.4   M
# 4    5  6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...  6.1  7.5  7.2   M
# 5    6  9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  ...  5.7  8.0  7.8   M
# 6    7  2.8  3.9  5.5  6.9  5.0  7.3  4.6  5.2  4.4  ...  6.6  6.0  6.0   F
# 7    8  8.3  6.0  7.6  5.1  7.5  4.7  5.8  7.2  6.7  ...  7.1  6.8  7.0   F
# 8    9  6.5  6.3  7.6  6.0  5.5  7.1  6.3  5.0  7.3  ...  9.1  7.9  6.1   F
# 9   10  7.3  5.9  4.7  7.1  6.7  7.9  6.7  7.7  8.0  ...  6.4  6.1  7.8   F
#
#    DT   KV   DH1   DH2   DH3  KT
# 0 NaN  2NT  3.25  3.25  4.50  A1
# 1 NaN    1  6.00  4.00  3.50   C
# ...

# %%
X = data[len(data) - 10: ]
X = pd.DataFrame(X)
X.head(10)
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...   X6   D6   N6  GT  \
# 90   91  8.1  7.7  9.1  8.5  6.1  8.6  8.8  7.3  8.8  ...  8.3  8.7  7.8   M
# 91   92  7.8  6.5  6.7  5.4  6.2  4.8  5.9  4.4  8.9  ...  7.2  7.4  7.0   M
# 92   93  5.0  6.6  6.5  7.2  5.8  6.7  6.4  6.0  6.8  ...  5.9  6.7  5.8   M
# 93   94  5.2  5.2  6.8  7.9  6.6  8.9  7.6  5.3  6.8  ...  8.7  7.8  5.0   M
# 94   95  5.8  5.9  7.6  6.1  5.3  8.1  6.1  5.0  6.4  ...  7.3  6.8  5.3   M
# 95   96  8.6  6.9  7.4  8.8  7.6  5.8  7.3  5.7  8.9  ...  6.3  6.1  6.2   F
# 96   97  3.7  5.4  6.0  5.1  5.5  3.9  6.1  4.4  4.1  ...  7.9  7.5  4.4   F
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  9.6  8.4  5.8   M
# 98   99  2.7  1.8  3.4  5.3  4.5  7.9  4.9  3.8  2.8  ...  6.6  5.2  5.9   M
# 99  100  4.1  5.2  4.9  5.3  5.5  5.4  7.2  5.4  4.4  ...  5.6  6.6  5.8   M
#
#     DT   KV   DH1   DH2   DH3  KT
# 90 NaN    2  6.25  4.00  6.50   A
# 91 NaN  2NT  4.75  4.75  4.50   A
# ...

# %%
data.tail(10)
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...   X6   D6   N6  GT  \
# 90   91  8.1  7.7  9.1  8.5  6.1  8.6  8.8  7.3  8.8  ...  8.3  8.7  7.8   M
# 91   92  7.8  6.5  6.7  5.4  6.2  4.8  5.9  4.4  8.9  ...  7.2  7.4  7.0   M
# 92   93  5.0  6.6  6.5  7.2  5.8  6.7  6.4  6.0  6.8  ...  5.9  6.7  5.8   M
# 93   94  5.2  5.2  6.8  7.9  6.6  8.9  7.6  5.3  6.8  ...  8.7  7.8  5.0   M
# 94   95  5.8  5.9  7.6  6.1  5.3  8.1  6.1  5.0  6.4  ...  7.3  6.8  5.3   M
# 95   96  8.6  6.9  7.4  8.8  7.6  5.8  7.3  5.7  8.9  ...  6.3  6.1  6.2   F
# 96   97  3.7  5.4  6.0  5.1  5.5  3.9  6.1  4.4  4.1  ...  7.9  7.5  4.4   F
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  9.6  8.4  5.8   M
# 98   99  2.7  1.8  3.4  5.3  4.5  7.9  4.9  3.8  2.8  ...  6.6  5.2  5.9   M
# 99  100  4.1  5.2  4.9  5.3  5.5  5.4  7.2  5.4  4.4  ...  5.6  6.6  5.8   M
#
#     DT   KV   DH1   DH2   DH3  KT
# 90 NaN    2  6.25  4.00  6.50   A
# 91 NaN  2NT  4.75  4.75  4.50   A
# ...

# %%
data.fillna(0, inplace = True)
data.tail(10)
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...   X6   D6   N6  GT  \
# 90   91  8.1  7.7  9.1  8.5  6.1  8.6  8.8  7.3  8.8  ...  8.3  8.7  7.8   M
# 91   92  7.8  6.5  6.7  5.4  6.2  4.8  5.9  4.4  8.9  ...  7.2  7.4  7.0   M
# 92   93  5.0  6.6  6.5  7.2  5.8  6.7  6.4  6.0  6.8  ...  5.9  6.7  5.8   M
# 93   94  5.2  5.2  6.8  7.9  6.6  8.9  7.6  5.3  6.8  ...  8.7  7.8  5.0   M
# 94   95  5.8  5.9  7.6  6.1  5.3  8.1  6.1  5.0  6.4  ...  7.3  6.8  5.3   M
# 95   96  8.6  6.9  7.4  8.8  7.6  5.8  7.3  5.7  8.9  ...  6.3  6.1  6.2   F
# 96   97  3.7  5.4  6.0  5.1  5.5  3.9  6.1  4.4  4.1  ...  7.9  7.5  4.4   F
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  9.6  8.4  5.8   M
# 98   99  2.7  1.8  3.4  5.3  4.5  7.9  4.9  3.8  2.8  ...  6.6  5.2  5.9   M
# 99  100  4.1  5.2  4.9  5.3  5.5  5.4  7.2  5.4  4.4  ...  5.6  6.6  5.8   M
#
#      DT   KV   DH1   DH2   DH3  KT
# 90  0.0    2  6.25  4.00  6.50   A
# 91  0.0  2NT  4.75  4.75  4.50   A
# ...

# %%
data["T1"].fillna(data["T1"].mean(), inplace = False)
# Out:
# 0     7.2
# 1     5.4
# 2     5.6
# 3     6.6
# 4     6.0
#      ...
# 95    8.6
# 96    3.7
# 97    8.8
# 98    2.7
# 99    4.1
# Name: T1, Length: 100, dtype: float64

# %%
def fillData(data, col): 
    return data[col].fillna(data[col].mean(), inplace = False)

for col in data.columns:
    datatype = str(data[col].dtype)
    if datatype in ["float64", "int64"]:
        fillData(data, col)

# %%
'''
TBM = (T*2 + L + H + S + V*2 + X + D + N) / 10
'''
for i in ["1", "2", "3"]:
    data["TBM" + i] = np.round(((data["T" + i] * 2) + data["L" + i] + data["H" + i] + data["S" + i] + (data["V" + i] * 2) + data['X' + i] + data['D' + i] + data['N' + i]) / 10, 2)

# %%
data.head(10)
# Out:
#    STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...   DH1   DH2   DH3  \
# 0    1  7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  3.25  3.25  4.50
# 1    2  5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...  6.00  4.00  3.50
# 2    3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  5.00  6.75  4.00
# 3    4  6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  4.25  4.25  5.25
# 4    5  6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...  4.25  4.50  5.00
# 5    6  9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  ...  1.50  4.00  6.00
# 6    7  2.8  3.9  5.5  6.9  5.0  7.3  4.6  5.2  4.4  ...  6.50  6.75  5.25
# 7    8  8.3  6.0  7.6  5.1  7.5  4.7  5.8  7.2  6.7  ...  3.75  4.50  4.25
# 8    9  6.5  6.3  7.6  6.0  5.5  7.1  6.3  5.0  7.3  ...  3.50  3.50  6.75
# 9   10  7.3  5.9  4.7  7.1  6.7  7.9  6.7  7.7  8.0  ...  4.00  4.75  5.50
#
#    KT  TBM1  TBM2  TBM3  XL1  XL2  XL3
# 0  A1  7.00  7.54  7.06    K    K    K
# 1   C  4.69  5.47  4.70    Y   TB    Y
# ...

# %% [markdown]
# # Bai 8

# %%
def evaluate(score):
    if score < 5.0: return "Y"
    elif 5.0 <= score < 6.5: return "TB"
    elif 6.5 <= score < 8.0: return "K"
    elif 8.0 <= score < 9.0: return "G"
    return "XS"

for i in ["1", "2", "3"]:
    col_name = data["TBM" + i].values
    tmp = []
    for col in col_name: tmp.append(evaluate(col))
    data["XL" + i] = tmp

# %%
data.head(10)
# Out:
#    STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...   DH1   DH2   DH3  \
# 0    1  7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  3.25  3.25  4.50
# 1    2  5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...  6.00  4.00  3.50
# 2    3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  5.00  6.75  4.00
# 3    4  6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  4.25  4.25  5.25
# 4    5  6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...  4.25  4.50  5.00
# 5    6  9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  ...  1.50  4.00  6.00
# 6    7  2.8  3.9  5.5  6.9  5.0  7.3  4.6  5.2  4.4  ...  6.50  6.75  5.25
# 7    8  8.3  6.0  7.6  5.1  7.5  4.7  5.8  7.2  6.7  ...  3.75  4.50  4.25
# 8    9  6.5  6.3  7.6  6.0  5.5  7.1  6.3  5.0  7.3  ...  3.50  3.50  6.75
# 9   10  7.3  5.9  4.7  7.1  6.7  7.9  6.7  7.7  8.0  ...  4.00  4.75  5.50
#
#    KT  TBM1  TBM2  TBM3  XL1  XL2  XL3
# 0  A1  7.00  7.54  7.06    K    K    K
# 1   C  4.69  5.47  4.70    Y   TB    Y
# ...

# %% [markdown]
# # Bai 9
# # Normalization score by using Min Max Normalization

# %%
def minMaxScaler(val_fl):
    return (val_fl * 4) / 10


for i in ["1", "2", "3"]:
    col_name = data[f"TBM{i}"]
    np_arr = np.array(col_name)
    data[f"US_TBM{i}"] = minMaxScaler(np_arr)

# %%
data.head(10)
# Out:
#    STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  KT  TBM1  TBM2  \
# 0    1  7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  A1  7.00  7.54
# 1    2  5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...   C  4.69  5.47
# 2    3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...   C  5.77  5.38
# 3    4  6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  D1  6.21  5.20
# 4    5  6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...   A  6.50  6.36
# 5    6  9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  ...  D1  7.96  8.54
# 6    7  2.8  3.9  5.5  6.9  5.0  7.3  4.6  5.2  4.4  ...   C  4.90  5.60
# 7    8  8.3  6.0  7.6  5.1  7.5  4.7  5.8  7.2  6.7  ...  D1  6.80  6.87
# 8    9  6.5  6.3  7.6  6.0  5.5  7.1  6.3  5.0  7.3  ...  D1  6.23  6.72
# 9   10  7.3  5.9  4.7  7.1  6.7  7.9  6.7  7.7  8.0  ...  D1  6.80  7.25
#
#    TBM3  XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3
# 0  7.06    K    K    K    2.800    3.016    2.824
# 1  4.70    Y   TB    Y    1.876    2.188    1.880
# ...

# %% [markdown]
# # Bai 10

# %%
'''
A = (DH1 * 2 + DH2 + DH3) / 4
B = (DH1 + DH2 * 2 + DH3) / 4
C = (DH1 + DH2 + DH3) / 3
'''
def transform(data, col):
    data[col] = data[col].map({True: "1", False: "0"})

dh1 = data["DH1"]
dh2 = data["DH2"]
dh3 = data["DH3"]

data["A"] = (dh1 * 2 + dh2 + dh3) / 4
data["B"] = (dh1 + dh2 * 2 + dh3) / 4
data["K"] = (dh1 + dh2 + dh3) / 3
data["A"] = data["A"] >= 5.0
data["B"] = data["B"] >= 5.0
data["K"] = data["K"] >= 5.0
transform(data, "A")
transform(data, "B")
transform(data, "K")

# %%
data.head(30)
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM3  XL1  XL2  \
# 0     1  7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  7.06    K    K
# 1     2  5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...  4.70    Y   TB
# 2     3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  4.33   TB   TB
# 3     4  6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  6.03   TB   TB
# 4     5  6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...  7.01    K   TB
# 5     6  9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  ...  7.82    K    G
# 6     7  2.8  3.9  5.5  6.9  5.0  7.3  4.6  5.2  4.4  ...  5.24    Y   TB
# 7     8  8.3  6.0  7.6  5.1  7.5  4.7  5.8  7.2  6.7  ...  6.95    K    K
# 8     9  6.5  6.3  7.6  6.0  5.5  7.1  6.3  5.0  7.3  ...  6.59   TB    K
# 9    10  7.3  5.9  4.7  7.1  6.7  7.9  6.7  7.7  8.0  ...  7.12    K    K
# 10   11  5.2  6.4  7.4  7.0  7.1  8.1  7.6  6.8  6.3  ...  7.65    K    K
# 11   12  7.9  7.0  9.1  8.6  6.1  7.0  5.6  9.0  8.2  ...  7.49    K    K
# ...

# %% [markdown]
# # Bai 11: Save file csv

# %%
data.to_csv("processed_dulieuxettuyendaihoc.csv")
